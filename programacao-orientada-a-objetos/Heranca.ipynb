# %%
class Jogador:

# %%
class Funcionario:
    def __init__(self, nome, salario):
        self.nome = nome
        self.salario = salario
        

class Gerente(Funcionario):
    def __init__(self, nome, salario,setor):
        super().__init__(nome, salario)
        self.setor = setor

# %%
class Funcionario:
    def mostrar(self):
        print("Funcionário comum")

class Gerente(Funcionario):
    def mostrar(self):
        super().mostrar()
        print("Gerente da empresa")


g = Gerente()
g.mostrar()
